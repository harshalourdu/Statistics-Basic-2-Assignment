# %% [markdown]
# # Q1. What are the three measures of central tendency?
# The three measures of central tendency are:
#
# Mean – The arithmetic average of a dataset, calculated by summing all values and dividing by the number of values.
# Median – The middle value in a dataset when the values are arranged in ascending or descending order. If there is an even number of values, the median is the average of the two middle values.
# Mode – The value that occurs most frequently in the dataset.
#
#
# # Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?
# Mean: The average value of the dataset. It is used when the data is symmetrically distributed and is sensitive to outliers.
# Median: The middle value that separates the dataset into two equal halves. It is often used when the dataset has outliers or is skewed.
# Mode: The value that appears most frequently. It is particularly useful for categorical data and identifying the most common item in the dataset.
#
#
#
# # Q3. Measure the three measures of central tendency for the given height data:
#
# Data=[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]
#
# Mean: Sum of all values divided by the number of values.
# Median: Middle value of the dataset after sorting.
# Mode: The value that occurs most frequently.
# Let's compute these values:
#
# Sorted Data:
# 172.5,175,175,176,176,176.2,176.5,177,177,177,178,178,178,178,178.2,178.9,179,180
#
# Mean:
#
# Mean=172.5+175+175+176+176+176.2+176.5+177+177+177+178+178+178+178+178.2+178.9+179+180
# ​
# Mean≈177.36
#
# Median: Since there are 18 data points (an even number), the median is the average of the 9th and 10th values. Sorted data:
#
# {172.5,175,175,176,176,176.2,176.5,177,177,177,178,178,178,178,178.2,178.9,179,180} The 9th and 10th values are both 177.
#
# Median=177+177/2=177
#
# Mode: The most frequent value is 178, which appears 5 times.
#
# Mode=178
#
#
#
# # Q4. Find the standard deviation for the given data:
#
# Data=[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]
#
# To compute the standard deviation:
#
# Find the mean.
#
# Subtract the mean from each data point and square the result.
#
# Find the average of those squared differences.
#
# Take the square root of that average.
#
# Let's calculate the standard deviation:
#
# Standard Deviation≈1.62
#
#
#
# # Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example.
#
# Range: The difference between the maximum and minimum values. It gives an idea of how spread out the values are.
#
# Variance: The average squared deviation of each data point from the mean. It measures the spread of the data but in squared units.
#
# Standard Deviation: The square root of the variance, it provides a measure of spread in the same units as the data.
#
#
#
# # Q6. What is a Venn diagram?
# A Venn diagram is a visual representation of the relationships between different sets. It uses overlapping circles to show which elements are shared between sets and which are unique to each set.
#
#
#
# # Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
#
# (i) A∩B (Intersection of A and B)
#
# (ii) A∪B (Union of A and B)
#
# (i) Intersection: A∩B={2,6}
#
# (ii) Union: A∪B={0,2,3,4,5,6,7,8,10}
#
#
#
# # Q8. What do you understand about skewness in data?
#
# Skewness refers to the asymmetry or lack of symmetry in the distribution of data:
#
# Positive skew (right skew): The right tail is longer, meaning the mean is greater than the median.
#
# Negative skew (left skew): The left tail is longer, meaning the mean is less than the median.
#
#
#
#
# # Q9. If a data is right skewed, what will be the position of the median with respect to the mean?
# In a right-skewed distribution, the mean is greater than the median, so the mean is located to the right of the median.
#
#
#
#
# # Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?
# Covariance measures the degree to which two variables change together. A positive covariance indicates that the variables tend to increase together, while a negative covariance indicates that one variable increases as the other decreases.
# Correlation standardizes covariance to provide a measure of the strength and direction of the relationship between two variables, ranging from -1 (perfect negative correlation) to +1 (perfect positive correlation).
#
#
#
# # Q12. For a normal distribution data, what is the relationship between its measures of central tendency?
# In a normal distribution, the mean, median, and mode are all equal and lie at the center of the distribution.
#
#
#
#
# # Q13. How is covariance different from correlation?
#
# Covariance measures the direction of the linear relationship between two variables but does not provide a standardized scale.
# Correlation standardizes the covariance, providing a measure of both the strength and direction of the linear relationship, with values between -1 and +1.
#
#
#
# # Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.
#
# Outliers can skew the mean, making it higher or lower than the central cluster of data. The median is less sensitive to outliers because it depends on the middle value. Dispersion measures like variance and standard deviation can also be greatly affected by outliers.
# ​
#
# ​
